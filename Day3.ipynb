# %%
#1st prgrm 
import numpy as np
arr = np.array([])
arr = np.arange(2,50,3)
print(arr)

# %%
#2nd prgrm

import numpy as np
lst1=[]
n= 5
for i in range(0,3):
    x =int(input('enter a value in list1'))
    lst1.append((x))
print(lst1)
lst2=[]
for i in range(0,3):
    y =int(input('enter a value in list2'))
    lst2.append((y))
print(lst2)
arr1= np.array(lst1)
arr2= np.array(lst2)
np.concatenate((arr1,arr2))
np.sort((arr1,arr2))

# %%
#3rd program
import numpy as np
ar1=np.arange(8)
print(ar1)
print('size is:',ar1.size)
print('dimension is:',ar1.ndim)

ar2=np.arange(12).reshape(3,4)
print(ar2)
print('size is:',ar2.size)
print('dimensions is :',ar2.ndim)

ar3=np.arange(24).reshape(2,3,4)
print(ar3)
print('size is:',ar3.size)
print('dimensions is: ',ar3.ndim)

# %%
#4th program

d1= np.array([1,2,3,4,5,6])
print(d1)
d2=np.reshape(d1,(3,2))
print(d2)

# %%
# 6th

lst=[1,2,5,5,6]
a_set=set(lst)
print(a_set,len(a_set))
